# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\aluis\OneDrive\Desktop\Google_Project\ppc_campaign_cleaned.csv")

# %%
df
# Out:
#     campaign_id  budget  clicks     ctr    cpc  conversions    cpa  \
# 0         C3578    6390     401  0.0461  15.94          174  36.72
# 1         C6702    9870    1286  0.2860   7.67          821  12.02
# 2         C9725    7700    1684  0.2122   4.57         1060   7.26
# 3         C9472    8420     444  0.0961  18.96          308  27.34
# 4         C7601    8470    1912  0.3652   4.43         1428   5.93
# ..          ...     ...     ...     ...    ...          ...    ...
# 995       C4071    7400     657  0.0986  11.26          136  54.41
# 996       C2402    3670    1534  0.1974   2.39         1258   2.92
# 997       C3257    4820     231  0.0238  20.87           83  58.07
# 998       C4315    9330     395  0.0517  23.62          239  39.04
# 999       C1412    3070     493  0.1965   6.23          415   7.40
#
#      conversion_rate  duration   platform content_type target_age  \
# 0             0.4339        20  Instagram     Carousel      35-44
# ...

# %%
df.campaign_id.nunique()
# Out:
# 954

# %%
df.shape
# Out:
# (1000, 19)

# %%
duplicate_ids = df['campaign_id'][df['campaign_id'].duplicated()]

# %%
duplicate_ids.shape
# Out:
# (46,)

# %%
df.platform.nunique()
# Out:
# 5

# %%
df[['campaign_id','spend','cpa','roas']]
# Out:
#     campaign_id    spend    cpa   roas
# 0         C3578   6453.9  36.72   4.31
# 1         C6702  10067.4  12.02  12.72
# 2         C9725   7623.0   7.26  25.45
# 3         C9472   8504.2  27.34   2.82
# 4         C7601   8046.5   5.93  34.43
# ..          ...      ...    ...    ...
# 995       C4071   7696.0  54.41   3.13
# 996       C2402   3523.2   2.92  58.56
# 997       C3257   5061.0  58.07   1.02
# 998       C4315   8956.8  39.04   3.95
# 999       C1412   3192.8   7.40  13.13
#
# [1000 rows x 4 columns]

# %%
df[df['campaign_id'].duplicated(keep=False)]
# Out:
#     campaign_id  budget  clicks     ctr    cpc  conversions    cpa  \
# 1         C6702    9870    1286  0.2860   7.67          821  12.02
# 2         C9725    7700    1684  0.2122   4.57         1060   7.26
# 12        C4133    7460    1326  0.1529   5.63          154  48.44
# 17        C6840    3290     376  0.1717   8.75          115  28.61
# 20        C9010    4120    1076  0.1946   3.83         1027   4.01
# ..          ...     ...     ...     ...    ...          ...    ...
# 959       C9240    2720    1253  0.2487   2.17          865   3.14
# 967       C3516    8740    1264  0.1546   6.91          734  11.91
# 972       C6242    9170    1005  0.1830   9.12          199  46.08
# 976       C8156    5160     279  0.0287  18.49           77  67.01
# 982       C2710    2290    1620  0.5633   1.41          398   5.75
#
#      conversion_rate  duration   platform content_type target_age  \
# 1             0.6384        28   LinkedIn         Text        55+
# ...

# %%
df['campaign_id'] = df['campaign_id'] + '_' + df.groupby('campaign_id').cumcount().astype(str)

# %%
df
# Out:
#     campaign_id  budget  clicks     ctr    cpc  conversions    cpa  \
# 0       C3578_0    6390     401  0.0461  15.94          174  36.72
# 1       C6702_0    9870    1286  0.2860   7.67          821  12.02
# 2       C9725_0    7700    1684  0.2122   4.57         1060   7.26
# 3       C9472_0    8420     444  0.0961  18.96          308  27.34
# 4       C7601_0    8470    1912  0.3652   4.43         1428   5.93
# ..          ...     ...     ...     ...    ...          ...    ...
# 995     C4071_0    7400     657  0.0986  11.26          136  54.41
# 996     C2402_0    3670    1534  0.1974   2.39         1258   2.92
# 997     C3257_0    4820     231  0.0238  20.87           83  58.07
# 998     C4315_0    9330     395  0.0517  23.62          239  39.04
# 999     C1412_0    3070     493  0.1965   6.23          415   7.40
#
#      conversion_rate  duration   platform content_type target_age  \
# 0             0.4339        20  Instagram     Carousel      35-44
# ...

# %%
df['campaign_id'].nunique()
# Out:
# 1000

# %%
df.describe()
# Out:
#             budget       clicks          ctr          cpc  conversions  \
# count  1000.000000  1000.000000  1000.000000  1000.000000   1000.00000
# mean   5961.990000  1013.229000     0.258417    11.230730    505.67200
# std    2326.091753   563.971223     0.262449    16.026811    424.76226
# min    2030.000000    50.000000     0.006100     1.080000     10.00000
# 25%    4007.500000   514.250000     0.094275     3.707500    153.75000
# 50%    5855.000000   996.500000     0.182150     5.755000    396.50000
# 75%    7960.000000  1491.500000     0.306900    11.285000    772.25000
# max    9990.000000  1996.000000     1.785100   132.310000   1894.00000
#
#                cpa  conversion_rate     duration        revenue         spend  \
# count  1000.000000      1000.000000  1000.000000    1000.000000   1000.000000
# mean     40.966170         0.508329    18.313000   59886.710000   5956.167800
# std      76.623075         0.284814     6.952796   60237.650065   2330.082996
# ...

# %%
df['campaign_id'].duplicated().sum()  # just IDs
# Out:
# 0

# %%
df.to_csv('ppc_campaign_clean_2.0.csv', index=False)
